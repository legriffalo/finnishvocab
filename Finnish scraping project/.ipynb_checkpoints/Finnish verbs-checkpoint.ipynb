# %%
#pip install

# %%
from bs4 import BeautifulSoup as bs
import pandas as pd
import urllib as url
from IPython.core.display import HTML
import time #set sleep to avoid url blocking scraper
import pygwalker as pyg
import keyboard

# %% [markdown]
# ### use this plan https://docs.google.com/spreadsheets/d/17qR2qHoPeY-O5WeixLloJ1rSaZYfYzgUqpbFAMgLvuo/edit?usp=sharing
#
# ### first step is to pull the list of all Finnish verbs from https://cooljugator.com/fi/list/all

# %%
doc = url.request.urlopen('https://cooljugator.com/fi/list/all').read()
soup = bs(doc,'html.parser')
soup.prettify()
links = soup.find_all('li')
# for i in range(41,50):
#     print(links[i])
verbs = [str(x).split(sep = '>')[1] for x in links]
verbs = [str(x).split(sep = '/')[-1] for x in verbs]
verbs = [str(x).replace('"','') for x in verbs]

translations = [str(x).split(sep = '>')[3] for x in links]
translations = [str(x).replace('- ','') for x in translations]
translations = [str(x).replace('</li','').lstrip() for x in translations]



translations
# for i in range(0,10):
#     print(verbs[i])
    
    
verb_df = pd.DataFrame({'Finnish infinitive':verbs,'English inifinitive':translations})
#verb_df.columns = ['infinitive','English']
verb_df = verb_df[:8092]
#verb_df.tail()

verb_df.to_csv("./Finnish verbs.csv", index = False)

# %% [markdown]
# # Revisiting to get Heidi to mark unused verbs (olde Finnish. vanha Suomi)

# %%
# recorded = keyboard.record(until='esc')
# # Then replay back at three times the speed.
# print(recorded)

# %%
# verbage = pd.read_csv('./Finnish verbs.csv')

# while True:  # making a loop
#     try:  # used try so that if user pressed other than the given key error will not be shown
#         if keyboard.is_pressed('4'):  # if key 'q' is pressed 
#             print(key)
            
#     except:
#         break  # if user pressed a key other than the given key the loop will break

# %% [markdown]
# # List built now to use if to iterate through and build verb data base

# %%
# scouting tables on site
doc = url.request.urlopen('https://fi.m.wiktionary.org/wiki/Liite:Verbitaivutus/suomi/lukea').read()
soup = bs(doc,'html.parser')
soup.prettify()
tables = soup.find_all('table')

for table in tables:
    display(HTML(str(table)))
    
    #columns = soup.find_all('th')
    #print(columns)
    print('table end \n\n\n\n')
# Out:
# <table class="piilotettu fi-taiv-vartalot-table"><caption>Vartalot
# </caption>
# <tbody><tr><td>vokaalivartalo</td>
# <td>-
# </td></tr><tr><td>heikko vokaalivartalo</td>
# <td>lue-
# </td></tr><tr><td>vahva vokaalivartalo</td>
# <td>luke-
# </td></tr><tr><td>konsonanttivartalo</td>
# <td>-
# </td></tr></tbody></table>
# table end
# <table class="wikitable" style="font-size:96%;white-space:nowrap;"><tbody><tr><th align="center" colspan="7" style="background:#e2e4c0">Indikatiivi
# </th></tr><tr><th align="center" colspan="3">preesens
# </th>
# <th align="center" colspan="1">
# </th>
# <th align="center" colspan="3">perfekti
# </th></tr><tr><th>persoona
# </th>
# <th>myönteinen
# </th>
# <th>kielteinen
# </th>
# <th>
# </th>
# <th>persoona
# </th>
# <th>myönteinen
# </th>
# <th>kielteinen
# </th></tr><tr><td>minä
# </td>
# <td><span class="Zzzz linkki" data-kuvaus="tm/*/v/ind.p.y1p" lang="fi"><a class="new" href="/w/index.php?title=luen&amp;action=edit&amp;redlink=1" title="luen (sivua ei ole)">luen</a></span>
# </td>
# <td>en <span class="Zzzz linkki" data-kuvaus="tm/*/v/imp.y2p imp.y2p.kon ind.kon" lang="fi"><a href="/wiki/lue#Suomi" title="lue">lue</a></span>
# </td>
# <td>
# </td>
# <td>minä
# </td>
# <td>olen <span class="Zzzz linkki" data-kuvaus="tm/fi/v/akt.pperf" data-kuvaus-param="{&amp;quot;8&amp;quot;:&amp;quot;lukea&amp;quot;}" lang="fi"><a href="/wiki/lukenut#Suomi" title="lukenut">lukenut</a></span>
# </td>
# <td>en ole <span class="Zzzz linkki" data-kuvaus="tm/fi/v/akt.pperf" data-kuvaus-param="{&amp;quot;8&amp;quot;:&amp;quot;lukea&amp;quot;}" lang="fi"><a href="/wiki/lukenut#Suomi" title="lukenut">lukenut</a></span>
# </td></tr><tr><td>sinä
# </td>
# <td><span class="Zzzz linkki" data-kuvaus="tm/*/v/ind.p.y2p" lang="fi"><a class="new" href="/w/index.php?title=luet&amp;action=edit&amp;redlink=1" title="luet (sivua ei ole)">luet</a></span>
# </td>
# <td>et <span class="Zzzz linkki" data-kuvaus="tm/*/v/imp.y2p imp.y2p.kon ind.kon" lang="fi"><a href="/wiki/lue#Suomi" title="lue">lue</a></span>
# </td>
# <td>
# </td>
# <td>sinä
# </td>
# <td>olet <span class="Zzzz linkki" data-kuvaus="tm/fi/v/akt.pperf" data-kuvaus-param="{&amp;quot;8&amp;quot;:&amp;quot;lukea&amp;quot;}" lang="fi"><a href="/wiki/lukenut#Suomi" title="lukenut">lukenut</a></span>
# </td>
# <td>et ole <span class="Zzzz linkki" data-kuvaus="tm/fi/v/akt.pperf" data-kuvaus-param="{&amp;quot;8&amp;quot;:&amp;quot;lukea&amp;quot;}" lang="fi"><a href="/wiki/lukenut#Suomi" title="lukenut">lukenut</a></span>
# </td></tr><tr><td>hän
# </td>
# <td><span class="Zzzz linkki" data-kuvaus="tm/*/v/ind.p.y3p" lang="fi"><a href="/wiki/lukee#Suomi" title="lukee">lukee</a></span>
# </td>
# <td>ei <span class="Zzzz linkki" data-kuvaus="tm/*/v/imp.y2p imp.y2p.kon ind.kon" lang="fi"><a href="/wiki/lue#Suomi" title="lue">lue</a></span>
# </td>
# <td>
# </td>
# <td>hän
# </td>
# <td>on <span class="Zzzz linkki" data-kuvaus="tm/fi/v/akt.pperf" data-kuvaus-param="{&amp;quot;8&amp;quot;:&amp;quot;lukea&amp;quot;}" lang="fi"><a href="/wiki/lukenut#Suomi" title="lukenut">lukenut</a></span>
# </td>
# <td>ei ole <span class="Zzzz linkki" data-kuvaus="tm/fi/v/akt.pperf" data-kuvaus-param="{&amp;quot;8&amp;quot;:&amp;quot;lukea&amp;quot;}" lang="fi"><a href="/wiki/lukenut#Suomi" title="lukenut">lukenut</a></span>
# </td></tr><tr><td>me
# </td>
# <td><span class="Zzzz linkki" data-kuvaus="tm/*/v/ind.p.m1p" lang="fi"><a class="new" href="/w/index.php?title=luemme&amp;action=edit&amp;redlink=1" title="luemme (sivua ei ole)">luemme</a></span>
# </td>
# <td>emme <span class="Zzzz linkki" data-kuvaus="tm/*/v/imp.y2p imp.y2p.kon ind.kon" lang="fi"><a href="/wiki/lue#Suomi" title="lue">lue</a></span>
# </td>
# <td>
# </td>
# <td>me
# </td>
# <td>olemme <span class="Zzzz linkki" data-kuvaus="tm/*/v/akt.pperf.mon" data-kuvaus-param="{&amp;quot;8&amp;quot;:{&amp;quot;1&amp;quot;:&amp;quot;lukenut&amp;quot;}}" lang="fi"><a class="new" href="/w/index.php?title=lukeneet&amp;action=edit&amp;redlink=1" title="lukeneet (sivua ei ole)">lukeneet</a></span>
# </td>
# <td>emme ole <span class="Zzzz linkki" data-kuvaus="tm/*/v/akt.pperf.mon" data-kuvaus-param="{&amp;quot;8&amp;quot;:{&amp;quot;1&amp;quot;:&amp;quot;lukenut&amp;quot;}}" lang="fi"><a class="new" href="/w/index.php?title=lukeneet&amp;action=edit&amp;redlink=1" title="lukeneet (sivua ei ole)">lukeneet</a></span>
# </td></tr><tr><td>te<br/>Te
# </td>
# <td><span class="Zzzz linkki" data-kuvaus="tm/*/v/ind.p.m2p" lang="fi"><a class="new" href="/w/index.php?title=luette&amp;action=edit&amp;redlink=1" title="luette (sivua ei ole)">luette</a></span><br/>-"-
# </td>
# <td>ette <span class="Zzzz linkki" data-kuvaus="tm/*/v/imp.y2p imp.y2p.kon ind.kon" lang="fi"><a href="/wiki/lue#Suomi" title="lue">lue</a></span><br/>-"-
# </td>
# <td>
# </td>
# <td>te<br/>Te
# </td>
# <td>olette <span class="Zzzz linkki" data-kuvaus="tm/*/v/akt.pperf.mon" data-kuvaus-param="{&amp;quot;8&amp;quot;:{&amp;quot;1&amp;quot;:&amp;quot;lukenut&amp;quot;}}" lang="fi"><a class="new" href="/w/index.php?title=lukeneet&amp;action=edit&amp;redlink=1" title="lukeneet (sivua ei ole)">lukeneet</a></span><br/>olette <span class="Zzzz linkki" data-kuvaus="tm/fi/v/akt.pperf" data-kuvaus-param="{&amp;quot;8&amp;quot;:&amp;quot;lukea&amp;quot;}" lang="fi"><a href="/wiki/lukenut#Suomi" title="lukenut">lukenut</a></span>
# </td>
# <td>ette ole <span class="Zzzz linkki" data-kuvaus="tm/*/v/akt.pperf.mon" data-kuvaus-param="{&amp;quot;8&amp;quot;:{&amp;quot;1&amp;quot;:&amp;quot;lukenut&amp;quot;}}" lang="fi"><a class="new" href="/w/index.php?title=lukeneet&amp;action=edit&amp;redlink=1" title="lukeneet (sivua ei ole)">lukeneet</a></span><br/>ette ole <span class="Zzzz linkki" data-kuvaus="tm/fi/v/akt.pperf" data-kuvaus-param="{&amp;quot;8&amp;quot;:&amp;quot;lukea&amp;quot;}" lang="fi"><a href="/wiki/lukenut#Suomi" title="lukenut">lukenut</a></span>
# </td></tr><tr><td>he
# </td>
# <td><span class="Zzzz linkki" data-kuvaus="tm/*/v/ind.p.m3p" lang="fi"><a class="new" href="/w/index.php?title=lukevat&amp;action=edit&amp;redlink=1" title="lukevat (sivua ei ole)">lukevat</a></span>
# </td>
# <td>eivät <span class="Zzzz linkki" data-kuvaus="tm/*/v/imp.y2p imp.y2p.kon ind.kon" lang="fi"><a href="/wiki/lue#Suomi" title="lue">lue</a></span>
# </td>
# <td>
# </td>
# <td>he
# </td>
# <td>ovat <span class="Zzzz linkki" data-kuvaus="tm/*/v/akt.pperf.mon" data-kuvaus-param="{&amp;quot;8&amp;quot;:{&amp;quot;1&amp;quot;:&amp;quot;lukenut&amp;quot;}}" lang="fi"><a class="new" href="/w/index.php?title=lukeneet&amp;action=edit&amp;redlink=1" title="lukeneet (sivua ei ole)">lukeneet</a></span>
# </td>
# <td>eivät ole <span class="Zzzz linkki" data-kuvaus="tm/*/v/akt.pperf.mon" data-kuvaus-param="{&amp;quot;8&amp;quot;:{&amp;quot;1&amp;quot;:&amp;quot;lukenut&amp;quot;}}" lang="fi"><a class="new" href="/w/index.php?title=lukeneet&amp;action=edit&amp;redlink=1" title="lukeneet (sivua ei ole)">lukeneet</a></span>
# </td></tr><tr><th align="center" colspan="3">
# </th>
# <th align="center" colspan="1">
# </th>
# <th align="center" colspan="3">
# </th></tr><tr><td><b>passiivi</b>
# </td>
# <td><span class="Zzzz linkki" data-kuvaus="tm/*/v/ind.prees.pass" lang="fi"><a class="new" href="/w/index.php?title=luetaan&amp;action=edit&amp;redlink=1" title="luetaan (sivua ei ole)">luetaan</a></span>
# </td>
# <td>ei <span class="Zzzz linkki" data-kuvaus="tm/*/v/ind.prees.pass.kon" lang="fi"><a class="new" href="/w/index.php?title=lueta&amp;action=edit&amp;redlink=1" title="lueta (sivua ei ole)">lueta</a></span>
# </td>
# <td>
# </td>
# <td><b>passiivi</b>
# </td>
# <td>on <span class="Zzzz linkki" data-kuvaus="tm/fi/v/pass.pperf" data-kuvaus-param="{&amp;quot;8&amp;quot;:&amp;quot;lukea&amp;quot;}" lang="fi"><a href="/wiki/luettu#Suomi" title="luettu">luettu</a></span>
# </td>
# <td>ei ole <span class="Zzzz linkki" data-kuvaus="tm/fi/v/pass.pperf" data-kuvaus-param="{&amp;quot;8&amp;quot;:&amp;quot;lukea&amp;quot;}" lang="fi"><a href="/wiki/luettu#Suomi" title="luettu">luettu</a></span>
# </td></tr><tr><th align="center" colspan="3">imperfekti
# </th>
# <th align="center" colspan="1">
# </th>
# <th align="center" colspan="3">pluskvamperfekti
# </th></tr><tr><th>persoona
# </th>
# <th>myönteinen
# </th>
# <th>kielteinen
# </th>
# <th>
# </th>
# <th>persoona
# </th>
# <th>myönteinen
# </th>
# <th>kielteinen
# </th></tr><tr><td>minä
# </td>
# <td><span class="Zzzz linkki" data-kuvaus="tm/*/v/ind.i.y1p" lang="fi"><a href="/wiki/luin#Suomi" title="luin">luin</a></span>
# </td>
# <td>en <span class="Zzzz linkki" data-kuvaus="tm/fi/v/akt.pperf" d
# table end
# <table class="wikitable" style="font-size:96%;white-space:nowrap;"><tbody><tr><th align="center" colspan="7" style="background:#c0cfe4">Konditionaali
# </th></tr><tr><th align="center" colspan="3">preesens
# </th>
# <th align="center" colspan="1">
# </th>
# <th align="center" colspan="3">perfekti
# </th></tr><tr><th>persoona
# </th>
# <th>myönteinen
# </th>
# <th>kielteinen
# </th>
# <th>
# </th>
# <th>persoona
# </th>
# <th>myönteinen
# </th>
# <th>kielteinen
# </th></tr><tr><td>minä
# </td>
# <td><span class="Zzzz linkki" data-kuvaus="tm/*/v/kond.y1p" lang="fi"><a class="new" href="/w/index.php?title=lukisin&amp;action=edit&amp;redlink=1" title="lukisin (sivua ei ole)">lukisin</a></span>
# </td>
# <td>en <span class="Zzzz linkki" data-kuvaus="tm/*/v/kond.kon kond.y3p" lang="fi"><a class="new" href="/w/index.php?title=lukisi&amp;action=edit&amp;redlink=1" title="lukisi (sivua ei ole)">lukisi</a></span>
# </td>
# <td>
# </td>
# <td>minä
# </td>
# <td>olisin <span class="Zzzz linkki" data-kuvaus="tm/fi/v/akt.pperf" data-kuvaus-param="{&amp;quot;8&amp;quot;:&amp;quot;lukea&amp;quot;}" lang="fi"><a href="/wiki/lukenut#Suomi" title="lukenut">lukenut</a></span>
# </td>
# <td>en olisi <span class="Zzzz linkki" data-kuvaus="tm/fi/v/akt.pperf" data-kuvaus-param="{&amp;quot;8&amp;quot;:&amp;quot;lukea&amp;quot;}" lang="fi"><a href="/wiki/lukenut#Suomi" title="lukenut">lukenut</a></span>
# </td></tr><tr><td>sinä
# </td>
# <td><span class="Zzzz linkki" data-kuvaus="tm/*/v/kond.y2p" lang="fi"><a class="new" href="/w/index.php?title=lukisit&amp;action=edit&amp;redlink=1" title="lukisit (sivua ei ole)">lukisit</a></span>
# </td>
# <td>et <span class="Zzzz linkki" data-kuvaus="tm/*/v/kond.kon kond.y3p" lang="fi"><a class="new" href="/w/index.php?title=lukisi&amp;action=edit&amp;redlink=1" title="lukisi (sivua ei ole)">lukisi</a></span>
# </td>
# <td>
# </td>
# <td>sinä
# </td>
# <td>olisit <span class="Zzzz linkki" data-kuvaus="tm/fi/v/akt.pperf" data-kuvaus-param="{&amp;quot;8&amp;quot;:&amp;quot;lukea&amp;quot;}" lang="fi"><a href="/wiki/lukenut#Suomi" title="lukenut">lukenut</a></span>
# </td>
# <td>et olisi <span class="Zzzz linkki" data-kuvaus="tm/fi/v/akt.pperf" data-kuvaus-param="{&amp;quot;8&amp;quot;:&amp;quot;lukea&amp;quot;}" lang="fi"><a href="/wiki/lukenut#Suomi" title="lukenut">lukenut</a></span>
# </td></tr><tr><td>hän
# </td>
# <td><span class="Zzzz linkki" data-kuvaus="tm/*/v/kond.kon kond.y3p" lang="fi"><a class="new" href="/w/index.php?title=lukisi&amp;action=edit&amp;redlink=1" title="lukisi (sivua ei ole)">lukisi</a></span>
# </td>
# <td>ei <span class="Zzzz linkki" data-kuvaus="tm/*/v/kond.kon kond.y3p" lang="fi"><a class="new" href="/w/index.php?title=lukisi&amp;action=edit&amp;redlink=1" title="lukisi (sivua ei ole)">lukisi</a></span>
# </td>
# <td>
# </td>
# <td>hän
# </td>
# <td>olisi <span class="Zzzz linkki" data-kuvaus="tm/fi/v/akt.pperf" data-kuvaus-param="{&amp;quot;8&amp;quot;:&amp;quot;lukea&amp;quot;}" lang="fi"><a href="/wiki/lukenut#Suomi" title="lukenut">lukenut</a></span>
# </td>
# <td>ei olisi <span class="Zzzz linkki" data-kuvaus="tm/fi/v/akt.pperf" data-kuvaus-param="{&amp;quot;8&amp;quot;:&amp;quot;lukea&amp;quot;}" lang="fi"><a href="/wiki/lukenut#Suomi" title="lukenut">lukenut</a></span>
# </td></tr><tr><td>me
# </td>
# <td><span class="Zzzz linkki" data-kuvaus="tm/*/v/kond.m1p" lang="fi"><a class="new" href="/w/index.php?title=lukisimme&amp;action=edit&amp;redlink=1" title="lukisimme (sivua ei ole)">lukisimme</a></span>
# </td>
# <td>emme <span class="Zzzz linkki" data-kuvaus="tm/*/v/kond.kon kond.y3p" lang="fi"><a class="new" href="/w/index.php?title=lukisi&amp;action=edit&amp;redlink=1" title="lukisi (sivua ei ole)">lukisi</a></span>
# </td>
# <td>
# </td>
# <td>me
# </td>
# <td>olisimme <span class="Zzzz linkki" data-kuvaus="tm/*/v/akt.pperf.mon" data-kuvaus-param="{&amp;quot;8&amp;quot;:{&amp;quot;1&amp;quot;:&amp;quot;lukenut&amp;quot;}}" lang="fi"><a class="new" href="/w/index.php?title=lukeneet&amp;action=edit&amp;redlink=1" title="lukeneet (sivua ei ole)">lukeneet</a></span>
# </td>
# <td>emme olisi <span class="Zzzz linkki" data-kuvaus="tm/*/v/akt.pperf.mon" data-kuvaus-param="{&amp;quot;8&amp;quot;:{&amp;quot;1&amp;quot;:&amp;quot;lukenut&amp;quot;}}" lang="fi"><a class="new" href="/w/index.php?title=lukeneet&amp;action=edit&amp;redlink=1" title="lukeneet (sivua ei ole)">lukeneet</a></span>
# </td></tr><tr><td>te<br/>Te
# </td>
# <td><span class="Zzzz linkki" data-kuvaus="tm/*/v/kond.m2p" lang="fi"><a class="new" href="/w/index.php?title=lukisitte&amp;action=edit&amp;redlink=1" title="lukisitte (sivua ei ole)">lukisitte</a></span><br/>-"-
# </td>
# <td>ette <span class="Zzzz linkki" data-kuvaus="tm/*/v/kond.kon kond.y3p" lang="fi"><a class="new" href="/w/index.php?title=lukisi&amp;action=edit&amp;redlink=1" title="lukisi (sivua ei ole)">lukisi</a></span><br/>-"-
# </td>
# <td>
# </td>
# <td>te<br/>Te
# </td>
# <td>olisitte <span class="Zzzz linkki" data-kuvaus="tm/*/v/akt.pperf.mon" data-kuvaus-param="{&amp;quot;8&amp;quot;:{&amp;quot;1&amp;quot;:&amp;quot;lukenut&amp;quot;}}" lang="fi"><a class="new" href="/w/index.php?title=lukeneet&amp;action=edit&amp;redlink=1" title="lukeneet (sivua ei ole)">lukeneet</a></span><br/>olisitte <span class="Zzzz linkki" data-kuvaus="tm/fi/v/akt.pperf" data-kuvaus-param="{&amp;quot;8&amp;quot;:&amp;quot;lukea&amp;quot;}" lang="fi"><a href="/wiki/lukenut#Suomi" title="lukenut">lukenut</a></span>
# </td>
# <td>ette olisi <span class="Zzzz linkki" data-kuvaus="tm/*/v/akt.pperf.mon" data-kuvaus-param="{&amp;quot;8&amp;quot;:{&amp;quot;1&amp;quot;:&amp;quot;lukenut&amp;quot;}}" lang="fi"><a class="new" href="/w/index.php?title=lukeneet&amp;action=edit&amp;redlink=1" title="lukeneet (sivua ei ole)">lukeneet</a></span><br/>ette olisi <span class="Zzzz linkki" data-kuvaus="tm/fi/v/akt.pperf" data-kuvaus-param="{&amp;quot;8&amp;quot;:&amp;quot;lukea&amp;quot;}" lang="fi"><a href="/wiki/lukenut#Suomi" title="lukenut">lukenut</a></span>
# </td></tr><tr><td>he
# </td>
# <td><span class="Zzzz linkki" data-kuvaus="tm/*/v/kond.m3p" lang="fi"><a class="new" href="/w/index.php?title=lukisivat&amp;action=edit&amp;redlink=1" title="lukisivat (sivua ei ole)">lukisivat</a></span>
# </td>
# <td>eivät <span class="Zzzz linkki" data-kuvaus="tm/*/v/kond.kon kond.y3p" lang="fi"><a class="new" href="/w/index.php?title=lukisi&amp;action=edit&amp;redlink=1" title="lukisi (sivua ei ole)">lukisi</a></span>
# </td>
# <td>
# </td>
# <td>he
# </td>
# <td>olisivat <span class="Zzzz linkki" data-kuvaus="tm/*/v/akt.pperf.mon" data-kuvaus-param="{&amp;quot;8&amp;quot;:{&amp;quot;1&amp;quot;:&amp;quot;lukenut&amp;quot;}}" lang="fi"><a class="new" href="/w/index.php?title=lukeneet&amp;action=edit&amp;redlink=1" title="lukeneet (sivua ei ole)">lukeneet</a></span>
# </td>
# <td>eivät olisi <span class="Zzzz linkki" data-kuvaus="tm/*/v/akt.pperf.mon" data-kuvaus-param="{&amp;quot;8&amp;quot;:{&amp;quot;1&amp;quot;:&amp;quot;lukenut&amp;quot;}}" lang="fi"><a class="new" href="/w/index.php?title=lukeneet&amp;action=edit&amp;redlink=1" title="lukeneet (sivua ei ole)">lukeneet</a></span>
# </td></tr><tr><th align="center" colspan="3">
# </th>
# <th align="center" colspan="1">
# </th>
# <th align="center" colspan="3">
# </th></tr><tr><td><b>passiivi</b>
# </td>
# <td><span class="Zzzz linkki" data-kuvaus="tm/*/v/kond.pass" lang="fi"><a class="new" href="/w/index.php?title=luettaisiin&amp;action=edit&amp;redlink=1" title="luettaisiin (sivua ei ole)">luettaisiin</a></span>
# </td>
# <td>ei <span class="Zzzz linkki" data-kuvaus="tm/*/v/kond.pass.kon" lang="fi"><a class="new" href="/w/index.php?title=luettaisi&amp;action=edit&amp;redlink=1" title="luettaisi (sivua ei ole)">luettaisi</a></span>
# </td>
# <td>
# </td>
# <td><b>passiivi</b>
# </td>
# <td>olisi <span class="Zzzz linkki" data-kuvaus="tm/fi/v/pass.pperf" data-kuvaus-param="{&amp;quot;8&amp;quot;:&amp;quot;lukea&amp;quot;}" lang="fi"><a href="/wiki/luettu#Suomi" title="luettu">luettu</a></span>
# </td>
# <td>ei olisi <span class="Zzzz linkki" data-kuvaus="tm/fi/v/pass.pperf" data-kuvaus-param="{&amp;quot;8&amp;quot;:&amp;quot;lukea&amp;quot;}" lang="fi"><a href="/wiki/luettu#Suomi" title="l
# table end
# <table class="wikitable" style="font-size:96%;white-space:nowrap;"><tbody><tr><th align="center" colspan="7" style="background:#c0e4c0">Potentiaali
# </th></tr><tr><th align="center" colspan="3">preesens
# </th>
# <th align="center" colspan="1">
# </th>
# <th align="center" colspan="3">perfekti
# </th></tr><tr><th>persoona
# </th>
# <th>myönteinen
# </th>
# <th>kielteinen
# </th>
# <th>
# </th>
# <th>persoona
# </th>
# <th>myönteinen
# </th>
# <th>kielteinen
# </th></tr><tr><td>minä
# </td>
# <td><span class="Zzzz linkki" data-kuvaus="tm/*/v/pot.y1p" lang="fi"><a class="new" href="/w/index.php?title=lukenen&amp;action=edit&amp;redlink=1" title="lukenen (sivua ei ole)">lukenen</a></span>
# </td>
# <td>en <span class="Zzzz linkki" data-kuvaus="tm/*/v/pot.kon" lang="fi"><a class="new" href="/w/index.php?title=lukene&amp;action=edit&amp;redlink=1" title="lukene (sivua ei ole)">lukene</a></span>
# </td>
# <td>
# </td>
# <td>minä
# </td>
# <td>lienen <span class="Zzzz linkki" data-kuvaus="tm/fi/v/akt.pperf" data-kuvaus-param="{&amp;quot;8&amp;quot;:&amp;quot;lukea&amp;quot;}" lang="fi"><a href="/wiki/lukenut#Suomi" title="lukenut">lukenut</a></span>
# </td>
# <td>en liene <span class="Zzzz linkki" data-kuvaus="tm/fi/v/akt.pperf" data-kuvaus-param="{&amp;quot;8&amp;quot;:&amp;quot;lukea&amp;quot;}" lang="fi"><a href="/wiki/lukenut#Suomi" title="lukenut">lukenut</a></span>
# </td></tr><tr><td>sinä
# </td>
# <td><span class="Zzzz linkki" data-kuvaus="tm/*/v/pot.y2p" lang="fi"><a class="new" href="/w/index.php?title=lukenet&amp;action=edit&amp;redlink=1" title="lukenet (sivua ei ole)">lukenet</a></span>
# </td>
# <td>et <span class="Zzzz linkki" data-kuvaus="tm/*/v/pot.kon" lang="fi"><a class="new" href="/w/index.php?title=lukene&amp;action=edit&amp;redlink=1" title="lukene (sivua ei ole)">lukene</a></span>
# </td>
# <td>
# </td>
# <td>sinä
# </td>
# <td>lienet <span class="Zzzz linkki" data-kuvaus="tm/fi/v/akt.pperf" data-kuvaus-param="{&amp;quot;8&amp;quot;:&amp;quot;lukea&amp;quot;}" lang="fi"><a href="/wiki/lukenut#Suomi" title="lukenut">lukenut</a></span>
# </td>
# <td>et liene <span class="Zzzz linkki" data-kuvaus="tm/fi/v/akt.pperf" data-kuvaus-param="{&amp;quot;8&amp;quot;:&amp;quot;lukea&amp;quot;}" lang="fi"><a href="/wiki/lukenut#Suomi" title="lukenut">lukenut</a></span>
# </td></tr><tr><td>hän
# </td>
# <td><span class="Zzzz linkki" data-kuvaus="tm/*/v/pot.y3p" lang="fi"><a class="new" href="/w/index.php?title=lukenee&amp;action=edit&amp;redlink=1" title="lukenee (sivua ei ole)">lukenee</a></span>
# </td>
# <td>ei <span class="Zzzz linkki" data-kuvaus="tm/*/v/pot.kon" lang="fi"><a class="new" href="/w/index.php?title=lukene&amp;action=edit&amp;redlink=1" title="lukene (sivua ei ole)">lukene</a></span>
# </td>
# <td>
# </td>
# <td>hän
# </td>
# <td>lienee <span class="Zzzz linkki" data-kuvaus="tm/fi/v/akt.pperf" data-kuvaus-param="{&amp;quot;8&amp;quot;:&amp;quot;lukea&amp;quot;}" lang="fi"><a href="/wiki/lukenut#Suomi" title="lukenut">lukenut</a></span>
# </td>
# <td>ei liene <span class="Zzzz linkki" data-kuvaus="tm/fi/v/akt.pperf" data-kuvaus-param="{&amp;quot;8&amp;quot;:&amp;quot;lukea&amp;quot;}" lang="fi"><a href="/wiki/lukenut#Suomi" title="lukenut">lukenut</a></span>
# </td></tr><tr><td>me
# </td>
# <td><span class="Zzzz linkki" data-kuvaus="tm/*/v/pot.m1p" lang="fi"><a class="new" href="/w/index.php?title=lukenemme&amp;action=edit&amp;redlink=1" title="lukenemme (sivua ei ole)">lukenemme</a></span>
# </td>
# <td>emme <span class="Zzzz linkki" data-kuvaus="tm/*/v/pot.kon" lang="fi"><a class="new" href="/w/index.php?title=lukene&amp;action=edit&amp;redlink=1" title="lukene (sivua ei ole)">lukene</a></span>
# </td>
# <td>
# </td>
# <td>me
# </td>
# <td>lienemme <span class="Zzzz linkki" data-kuvaus="tm/*/v/akt.pperf.mon" data-kuvaus-param="{&amp;quot;8&amp;quot;:{&amp;quot;1&amp;quot;:&amp;quot;lukenut&amp;quot;}}" lang="fi"><a class="new" href="/w/index.php?title=lukeneet&amp;action=edit&amp;redlink=1" title="lukeneet (sivua ei ole)">lukeneet</a></span>
# </td>
# <td>emme liene <span class="Zzzz linkki" data-kuvaus="tm/*/v/akt.pperf.mon" data-kuvaus-param="{&amp;quot;8&amp;quot;:{&amp;quot;1&amp;quot;:&amp;quot;lukenut&amp;quot;}}" lang="fi"><a class="new" href="/w/index.php?title=lukeneet&amp;action=edit&amp;redlink=1" title="lukeneet (sivua ei ole)">lukeneet</a></span>
# </td></tr><tr><td>te<br/>Te
# </td>
# <td><span class="Zzzz linkki" data-kuvaus="tm/*/v/pot.m2p" lang="fi"><a class="new" href="/w/index.php?title=lukenette&amp;action=edit&amp;redlink=1" title="lukenette (sivua ei ole)">lukenette</a></span><br/>-"-
# </td>
# <td>ette <span class="Zzzz linkki" data-kuvaus="tm/*/v/pot.kon" lang="fi"><a class="new" href="/w/index.php?title=lukene&amp;action=edit&amp;redlink=1" title="lukene (sivua ei ole)">lukene</a></span><br/>-"-
# </td>
# <td>
# </td>
# <td>te<br/>Te
# </td>
# <td>lienette <span class="Zzzz linkki" data-kuvaus="tm/*/v/akt.pperf.mon" data-kuvaus-param="{&amp;quot;8&amp;quot;:{&amp;quot;1&amp;quot;:&amp;quot;lukenut&amp;quot;}}" lang="fi"><a class="new" href="/w/index.php?title=lukeneet&amp;action=edit&amp;redlink=1" title="lukeneet (sivua ei ole)">lukeneet</a></span><br/>lienette <span class="Zzzz linkki" data-kuvaus="tm/fi/v/akt.pperf" data-kuvaus-param="{&amp;quot;8&amp;quot;:&amp;quot;lukea&amp;quot;}" lang="fi"><a href="/wiki/lukenut#Suomi" title="lukenut">lukenut</a></span>
# </td>
# <td>ette liene <span class="Zzzz linkki" data-kuvaus="tm/*/v/akt.pperf.mon" data-kuvaus-param="{&amp;quot;8&amp;quot;:{&amp;quot;1&amp;quot;:&amp;quot;lukenut&amp;quot;}}" lang="fi"><a class="new" href="/w/index.php?title=lukeneet&amp;action=edit&amp;redlink=1" title="lukeneet (sivua ei ole)">lukeneet</a></span><br/>ette liene <span class="Zzzz linkki" data-kuvaus="tm/fi/v/akt.pperf" data-kuvaus-param="{&amp;quot;8&amp;quot;:&amp;quot;lukea&amp;quot;}" lang="fi"><a href="/wiki/lukenut#Suomi" title="lukenut">lukenut</a></span>
# </td></tr><tr><td>he
# </td>
# <td><span class="Zzzz linkki" data-kuvaus="tm/*/v/pot.m3p" lang="fi"><a class="new" href="/w/index.php?title=lukenevat&amp;action=edit&amp;redlink=1" title="lukenevat (sivua ei ole)">lukenevat</a></span>
# </td>
# <td>eivät <span class="Zzzz linkki" data-kuvaus="tm/*/v/pot.kon" lang="fi"><a class="new" href="/w/index.php?title=lukene&amp;action=edit&amp;redlink=1" title="lukene (sivua ei ole)">lukene</a></span>
# </td>
# <td>
# </td>
# <td>he
# </td>
# <td>lienevät <span class="Zzzz linkki" data-kuvaus="tm/*/v/akt.pperf.mon" data-kuvaus-param="{&amp;quot;8&amp;quot;:{&amp;quot;1&amp;quot;:&amp;quot;lukenut&amp;quot;}}" lang="fi"><a class="new" href="/w/index.php?title=lukeneet&amp;action=edit&amp;redlink=1" title="lukeneet (sivua ei ole)">lukeneet</a></span>
# </td>
# <td>eivät liene <span class="Zzzz linkki" data-kuvaus="tm/*/v/akt.pperf.mon" data-kuvaus-param="{&amp;quot;8&amp;quot;:{&amp;quot;1&amp;quot;:&amp;quot;lukenut&amp;quot;}}" lang="fi"><a class="new" href="/w/index.php?title=lukeneet&amp;action=edit&amp;redlink=1" title="lukeneet (sivua ei ole)">lukeneet</a></span>
# </td></tr><tr><th align="center" colspan="3">
# </th>
# <th align="center" colspan="1">
# </th>
# <th align="center" colspan="3">
# </th></tr><tr><td><b>passiivi</b>
# </td>
# <td><span class="Zzzz linkki" data-kuvaus="tm/*/v/pot.pass" lang="fi"><a class="new" href="/w/index.php?title=luettaneen&amp;action=edit&amp;redlink=1" title="luettaneen (sivua ei ole)">luettaneen</a></span>
# </td>
# <td>ei <span class="Zzzz linkki" data-kuvaus="tm/*/v/pot.pass.kon" lang="fi"><a class="new" href="/w/index.php?title=luettane&amp;action=edit&amp;redlink=1" title="luettane (sivua ei ole)">luettane</a></span>
# </td>
# <td>
# </td>
# <td><b>passiivi</b>
# </td>
# <td>lienee <span class="Zzzz linkki" data-kuvaus="tm/fi/v/pass.pperf" data-kuvaus-param="{&amp;quot;8&amp;quot;:&amp;quot;lukea&amp;quot;}" lang="fi"><a href="/wiki/luettu#Suomi" title="luettu">luettu</a></span>
# </td>
# <td>ei liene <span class="Zzzz linkki" data-kuvaus="tm/fi/v/pass.pperf" data-kuvaus-param="{&amp;quot;8&amp;quot;:&amp;quot;lukea&amp;quot;}" lang="fi"><a href="/wiki/luettu#Suomi" title="luettu">luettu</a></span>
# </td></tr></tbody></table>
# table end
# <table class="wikitable" style="font-size:96%;white-space:nowrap;"><tbody><tr><th align="center" colspan="7" style="background:#e4d4c0">Imperatiivi
# </th></tr><tr><th align="center" colspan="3">preesens
# </th>
# <th align="center" colspan="1">
# </th>
# <th align="center" colspan="3">perfekti
# </th></tr><tr><th>persoona
# </th>
# <th>myönteinen
# </th>
# <th>kielteinen
# </th>
# <th>
# </th>
# <th>persoona
# </th>
# <th>myönteinen
# </th>
# <th>kielteinen
# </th></tr><tr><td>minä
# </td>
# <td>–
# </td>
# <td>–
# </td>
# <td>
# </td>
# <td>minä
# </td>
# <td>–
# </td>
# <td>–
# </td></tr><tr><td>sinä
# </td>
# <td><span class="Zzzz linkki" data-kuvaus="tm/*/v/imp.y2p imp.y2p.kon ind.kon" lang="fi"><a href="/wiki/lue#Suomi" title="lue">lue</a></span>
# </td>
# <td>älä <span class="Zzzz linkki" data-kuvaus="tm/*/v/imp.y2p imp.y2p.kon ind.kon" lang="fi"><a href="/wiki/lue#Suomi" title="lue">lue</a></span>
# </td>
# <td>
# </td>
# <td>sinä
# </td>
# <td>–
# </td>
# <td>–
# </td></tr><tr><td>hän
# </td>
# <td><span class="Zzzz linkki" data-kuvaus="tm/*/v/imp.y3p" lang="fi"><a class="new" href="/w/index.php?title=lukekoon&amp;action=edit&amp;redlink=1" title="lukekoon (sivua ei ole)">lukekoon</a></span>
# </td>
# <td>älköön <span class="Zzzz linkki" data-kuvaus="tm/*/v/imp.kon" lang="fi"><a class="new" href="/w/index.php?title=lukeko&amp;action=edit&amp;redlink=1" title="lukeko (sivua ei ole)">lukeko</a></span>
# </td>
# <td>
# </td>
# <td>hän
# </td>
# <td>olkoon <span class="Zzzz linkki" data-kuvaus="tm/fi/v/akt.pperf" data-kuvaus-param="{&amp;quot;8&amp;quot;:&amp;quot;lukea&amp;quot;}" lang="fi"><a href="/wiki/lukenut#Suomi" title="lukenut">lukenut</a></span>
# </td>
# <td>älköön olko <span class="Zzzz linkki" data-kuvaus="tm/fi/v/akt.pperf" data-kuvaus-param="{&amp;quot;8&amp;quot;:&amp;quot;lukea&amp;quot;}" lang="fi"><a href="/wiki/lukenut#Suomi" title="lukenut">lukenut</a></span>
# </td></tr><tr><td>me
# </td>
# <td><span class="Zzzz linkki" data-kuvaus="tm/*/v/imp.m1p" lang="fi"><a class="new" href="/w/index.php?title=lukekaamme&amp;action=edit&amp;redlink=1" title="lukekaamme (sivua ei ole)">lukekaamme</a></span>
# </td>
# <td>älkäämme <span class="Zzzz linkki" data-kuvaus="tm/*/v/imp.kon" lang="fi"><a class="new" href="/w/index.php?title=lukeko&amp;action=edit&amp;redlink=1" title="lukeko (sivua ei ole)">lukeko</a></span>
# </td>
# <td>
# </td>
# <td>me
# </td>
# <td>–
# </td>
# <td>–
# </td></tr><tr><td>te<br/>Te
# </td>
# <td><span class="Zzzz linkki" data-kuvaus="tm/*/v/imp.m2p" lang="fi"><a class="new" href="/w/index.php?title=lukekaa&amp;action=edit&amp;redlink=1" title="lukekaa (sivua ei ole)">lukekaa</a></span><br/>-"-
# </td>
# <td>älkää <span class="Zzzz linkki" data-kuvaus="tm/*/v/imp.kon" lang="fi"><a class="new" href="/w/index.php?title=lukeko&amp;action=edit&amp;redlink=1" title="lukeko (sivua ei ole)">lukeko</a></span><br/>-"-
# </td>
# <td>
# </td>
# <td>te<br/>Te
# </td>
# <td>–
# </td>
# <td>–
# </td></tr><tr><td>he
# </td>
# <td><span class="Zzzz linkki" data-kuvaus="tm/*/v/imp.m3p" lang="fi"><a class="new" href="/w/index.php?title=lukekoot&amp;action=edit&amp;redlink=1" title="lukekoot (sivua ei ole)">lukekoot</a></span>
# </td>
# <td>älkööt <span class="Zzzz linkki" data-kuvaus="tm/*/v/imp.kon" lang="fi"><a class="new" href="/w/index.php?title=lukeko&amp;action=edit&amp;redlink=1" title="lukeko (sivua ei ole)">lukeko</a></span>
# </td>
# <td>
# </td>
# <td>he
# </td>
# <td>olkoot <span class="Zzzz linkki" data-kuvaus="tm/*/v/akt.pperf.mon" data-kuvaus-param="{&amp;quot;8&amp;quot;:{&amp;quot;1&amp;quot;:&amp;quot;lukenut&amp;quot;}}" lang="fi"><a class="new" href="/w/index.php?title=lukeneet&amp;action=edit&amp;redlink=1" title="lukeneet (sivua ei ole)">lukeneet</a></span>
# </td>
# <td>älkööt olko <span class="Zzzz linkki" data-kuvaus="tm/*/v/akt.pperf.mon" data-kuvaus-param="{&amp;quot;8&amp;quot;:{&amp;quot;1&amp;quot;:&amp;quot;lukenut&amp;quot;}}" lang="fi"><a class="new" href="/w/index.php?title=lukeneet&amp;action=edit&amp;redlink=1" title="lukeneet (sivua ei ole)">lukeneet</a></span>
# </td></tr><tr><th align="center" colspan="3">
# </th>
# <th align="center" colspan="1">
# </th>
# <th align="center" colspan="3">
# </th></tr><tr><td><b>passiivi</b>
# </td>
# <td><span class="Zzzz linkki" data-kuvaus="tm/*/v/imp.pass" lang="fi"><a class="new" href="/w/index.php?title=luettakoon&amp;action=edit&amp;redlink=1" title="luettakoon (sivua ei ole)">luettakoon</a></span>
# </td>
# <td>älköön <span class="Zzzz linkki" data-kuvaus="tm/*/v/imp.pass.kon" lang="fi"><a class="new" href="/w/index.php?title=luettako&amp;action=edit&amp;redlink=1" title="luettako (sivua ei ole)">luettako</a></span>
# </td>
# <td>
# </td>
# <td><b>passiivi</b>
# </td>
# <td>olkoon <span class="Zzzz linkki" data-kuvaus="tm/fi/v/pass.pperf" data-kuvaus-param="{&amp;quot;8&amp;quot;:&amp;quot;lukea&amp;quot;}" lang="fi"><a href="/wiki/luettu#Suomi" title="luettu">luettu</a></span>
# </td>
# <td>älköön olko <span class="Zzzz linkki" data-kuvaus="tm/fi/v/pass.pperf" data-kuvaus-param="{&amp;quot;8&amp;quot;:&amp;quot;lukea&amp;quot;}" lang="fi"><a href="/wiki/luettu#Suomi" title="luettu">luettu</a></span>
# </td></tr></tbody></table>
# table end
# <table class="wikitable" style="font-size:96%;white-space:nowrap;"><tbody><tr><th colspan="4" style="background:rgb(80%,80%,100%)" width="50%">infinitiivit
# </th>
# <th colspan="3" style="background:rgb(80%,80%,100%)" width="50%">partisiipit
# </th></tr><tr><td colspan="2" style="background:rgb(80%,80%,100%)">
# </td>
# <th width="25%">aktiivi
# </th>
# <th width="25%">passiivi
# </th>
# <td style="background:rgb(80%,80%,100%)">
# </td>
# <th width="25%">aktiivi
# </th>
# <th width="25%">passiivi
# </th></tr><tr><th colspan="2" style="background:rgb(80%,80%,100%)">1.
# </th>
# <td colspan="2" style="background:rgb(95%,95%,100%)"><b>lukea</b>
# </td>
# <th style="background:rgb(80%,80%,100%)">preesens
# </th>
# <td style="background:rgb(95%,95%,100%)"><span class="Zzzz linkki" data-kuvaus="tm/fi/v/akt.pprees" data-kuvaus-param="{&amp;quot;8&amp;quot;:&amp;quot;lukea&amp;quot;}" lang="fi"><a href="/wiki/lukeva#Suomi" title="lukeva">lukeva</a></span>
# </td>
# <td style="background:rgb(95%,95%,100%)"><span class="Zzzz linkki" data-kuvaus="tm/fi/v/pass.pprees" data-kuvaus-param="{&amp;quot;8&amp;quot;:&amp;quot;lukea&amp;quot;}" lang="fi"><a href="/wiki/luettava#Suomi" title="luettava">luettava</a></span>
# </td></tr><tr><th colspan="2" style="background:rgb(80%,80%,100%)">pitkä 1.
# </th>
# <td colspan="2" style="background:rgb(95%,95%,100%)"><span class="Zzzz linkki" data-kuvaus="tm/fi/v/1.inf.pitkä" data-kuvaus-param="{&amp;quot;8&amp;quot;:&amp;quot;lukeakse&amp;quot;,&amp;quot;9&amp;quot;:&amp;quot;a&amp;quot;}" lang="fi"><a class="new" href="/w/index.php?title=lukeakseen&amp;action=edit&amp;redlink=1" title="lukeakseen (sivua ei ole)">lukeakseen</a></span><sup>1</sup></td>
# <th style="background:rgb(80%,80%,100%)">perfekti
# </th>
# <td style="background:rgb(95%,95%,100%)"><span class="Zzzz linkki" data-kuvaus="tm/fi/v/akt.pperf" data-kuvaus-param="{&amp;quot;8&amp;quot;:&amp;quot;lukea&amp;quot;}" lang="fi"><a href="/wiki/lukenut#Suomi" title="lukenut">lukenut</a></span>
# </td>
# <td style="background:rgb(95%,95%,100%)"><span class="Zzzz linkki" data-kuvaus="tm/fi/v/pass.pperf" data-kuvaus-param="{&amp;quot;8&amp;quot;:&amp;quot;lukea&amp;quot;}" lang="fi"><a href="/wiki/luettu#Suomi" title="luettu">luettu</a></span>
# </td></tr><tr><th rowspan="2" style="background:rgb(80%,80%,100%)">2.
# </th>
# <th>inessiivi
# </th>
# <td style="background:rgb(95%,95%,100%)"><span class="Zzzz linkki" data-kuvaus="tm/fi/v/2.inf.iness.akt" data-kuvaus-param="{&amp;quot;8&amp;quot;:&amp;quot;lukea&amp;quot;}" lang="fi"><a class="new" href="/w/index.php?title=lukiessa&amp;action=edit&amp;redlink=1" title="lukiessa (sivua ei ole)">lukiessa</a></span><sup>2</sup></td>
# <td style="background:rgb(95%,95%,100%)"><span class="Zzzz linkki" data-kuvaus="tm/fi/v/2.inf.iness.pass" data-kuvaus-param="{&amp;quot;8&amp;quot;:&amp;quot;lukea&amp;quot;}" lang="fi"><a class="new" href="/w/index.php?title=luettaessa&amp;action=edit&amp;redlink=1" title="luettaessa (sivua ei ole)">luettaessa</a></span>
# </td>
# <th style="background:rgb(80%,80%,100%)">agentti
# </th>
# <td colspan="2" style="background:rgb(95%,95%,100%)"><span class="Zzzz linkki" data-kuvaus="tm/fi/v/agpart" data-kuvaus-param="{&amp;quot;8&amp;quot;:&amp;quot;lukea&amp;quot;}" lang="fi"><a href="/wiki/lukema#Suomi" title="lukema">lukema</a></span><sup>4</sup></td></tr><tr><th>instruktiivi
# </th>
# <td style="background:rgb(95%,95%,100%)"><span class="Zzzz linkki" data-kuvaus="tm/fi/v/2.inf.ins" data-kuvaus-param="{&amp;quot;8&amp;quot;:&amp;quot;lukea&amp;quot;}" lang="fi"><a href="/wiki/lukien#Suomi" title="lukien">lukien</a></span>
# </td>
# <td style="background:rgb(95%,95%,100%)">–
# </td>
# <th style="background:rgb(80%,80%,100%)">kielteinen agentti
# </th>
# <td colspan="2" style="background:rgb(95%,95%,100%)"><span class="Zzzz linkki" data-kuvaus="tm/fi/v/agpart.neg" data-kuvaus-param="{&amp;quot;8&amp;quot;:&amp;quot;lukea&amp;quot;}" lang="fi"><a href="/wiki/lukematon#Suomi" title="lukematon">lukematon</a></span>
# </td></tr><tr><th rowspan="6" style="background:rgb(80%,80%,100%)">3.
# </th>
# <th>inessiivi
# </th>
# <td style="background:rgb(95%,95%,100%)"><span class="Zzzz linkki" data-kuvaus="tm/*/v/3.inf.iness" lang="fi"><a class="new" href="/w/index.php?title=lukemassa&amp;action=edit&amp;redlink=1" title="lukemassa (sivua ei ole)">lukemassa</a></span>
# </td>
# <td style="background:rgb(95%,95%,100%)">–
# </td>
# <td colspan="3" rowspan="9" style="background:rgb(95%,95%,100%);text-align:left;vertical-align:top;font-size:smaller;"><sup>1)</sup> käytetään vain <a href="/wiki/Luokka:Suomen_kielen_possessiivisuffiksit" title="Luokka:Suomen kielen possessiivisuffiksit">omistusliitteen</a> kanssa; tämä on yksikön ja monikon kolmannen persoonan muoto<br/><p><sup>2)</sup> voidaan käyttää <a href="/wiki/Luokka:Suomen_kielen_possessiivisuffiksit" title="Luokka:Suomen kielen possessiivisuffiksit">omistusliitteen</a> kanssa<br/><sup>3)</sup> käytetään vain <a href="/wiki/Luokka:Suomen_kielen_possessiivisuffiksit" title="Luokka:Suomen kielen possessiivisuffiksit">omistusliitteen</a> kanssa; tämä on yksikön ja monikon kolmannen persoonan muoto<br/><sup>4)</sup> käytetään vain transitiiviverbeistä kuten "tehdä", esim. "äidin tekemä ruoka"; ei intransitiiviverbeistä kuten "kuolla"
# </p>
# </td></tr><tr><th>elatiivi
# </th>
# <td style="background:rgb(95%,95%,100%)"><span class="Zzzz linkki" data-kuvaus="tm/*/v/3.inf.elat" lang="fi"><a class="new" href="/w/index.php?title=lukemasta&amp;action=edit&amp;redlink=1" title="lukemasta (sivua ei ole)">lukemasta</a></span>
# </td>
# <td style="background:rgb(95%,95%,100%)">–
# </td></tr><tr><th>illatiivi
# </th>
# <td style="background:rgb(95%,95%,100%)"><span class="Zzzz linkki" data-kuvaus="tm/*/v/3.inf.ill" lang="fi"><a href="/wiki/lukemaan#Suomi" title="lukemaan">lukemaan</a></span>
# </td>
# <td style="background:rgb(95%,95%,100%)">–
# </td></tr><tr><th>adessiivi
# </th>
# <td style="background:rgb(95%,95%,100%)"><span class="Zzzz linkki" data-kuvaus="tm/*/v/3.inf.adess" lang="fi"><a class="new" href="/w/index.php?title=lukemalla&amp;action=edit&amp;redlink=1" title="lukemalla (sivua ei ole)">lukemalla</a></span>
# </td>
# <td style="background:rgb(95%,95%,100%)">–
# </td></tr><tr><th>abessiivi
# </th>
# <td style="background:rgb(95%,95%,100%)"><span class="Zzzz linkki" data-kuvaus="tm/*/v/3.inf.abess" lang="fi"><a class="new" href="/w/index.php?title=lukematta&amp;action=edit&amp;redlink=1" title="lukematta (sivua ei ole)">lukematta</a></span>
# </td>
# <td style="background:rgb(95%,95%,100%)">–
# </td></tr><tr><th>instruktiivi
# </th>
# <td style="background:rgb(95%,95%,100%)"><span class="Zzzz linkki" data-kuvaus="tm/fi/v/3.inf.ins.akt" data-kuvaus-param="{&amp;quot;8&amp;quot;:&amp;quot;lukea&amp;quot;}" lang="fi"><a href="/wiki/lukeman#Suomi" title="lukeman">lukeman</a></span>
# </td>
# <td style="background:rgb(95%,95%,100%)"><span class="Zzzz linkki" data-kuvaus="tm/fi/v/3.inf.ins.pass" data-kuvaus-param="{&amp;quot;8&amp;quot;:&amp;quot;lukea&amp;quot;}" lang="fi"><a class="new" href="/w/index.php?title=luettaman&amp;action=edit&amp;redlink=1" title="luettaman (sivua ei ole)">luettaman</a></span>
# </td></tr><tr><th colspan="2" style="background:rgb(80%,80%,100%)">4.
# </th>
# <td colspan="2" style="background:rgb(95%,95%,100%)"><span class="Zzzz linkki" data-kuvaus="tm/*/v/4.inf.nom" lang="fi"><a href="/wiki/lukeminen#Suomi" title="lukeminen">lukeminen</a></span>
# </td></tr><tr><th colspan="2" style="background:rgb(80%,80%,100%)">5
# </th>
# <td colspan="2" style="background:rgb(95%,95%,100%)"><span class="Zzzz linkki" data-kuvaus="tm/fi/v/5.inf" data-kuvaus-param="{&amp;quot;8&amp;quot;:&amp;quot;lukemaisilla&amp;quot;,&amp;quot;9&amp;quot;:&amp;quot;a&amp;quot;}" lang="fi"><a class="new" href="/w/index.php?title=lukemaisillaan&amp;action=edit&amp;redlink=1" title="lukemaisillaan (sivua ei ole)">lukemaisillaan</a></span><sup>3</sup></td></tr></tbody></table>
# table end

# %%
#scouting for paricular lines/format
doc = url.request.urlopen('https://fi.m.wiktionary.org/wiki/Liite:Verbitaivutus/suomi/lukea').read()
soup = bs(doc,'html.parser')
soup.prettify()
tables = soup.find_all('table')
#table 1 
rows = tables[1].find_all('tr')
#HTML(str(rows))
rows = rows[3:4].copy()
rows[0]
#display(HTML(rows[0]))

y = []
for row in rows:
    x = []
    display(HTML(str(row)))
# Out:
# <tr><td>minä
# </td>
# <td><span class="Zzzz linkki" data-kuvaus="tm/*/v/ind.p.y1p" lang="fi"><a class="new" href="/w/index.php?title=luen&amp;action=edit&amp;redlink=1" title="luen (sivua ei ole)">luen</a></span>
# </td>
# <td>en <span class="Zzzz linkki" data-kuvaus="tm/*/v/imp.y2p imp.y2p.kon ind.kon" lang="fi"><a href="/wiki/lue#Suomi" title="lue">lue</a></span>
# </td>
# <td>
# </td>
# <td>minä
# </td>
# <td>olen <span class="Zzzz linkki" data-kuvaus="tm/fi/v/akt.pperf" data-kuvaus-param="{&amp;quot;8&amp;quot;:&amp;quot;lukea&amp;quot;}" lang="fi"><a href="/wiki/lukenut#Suomi" title="lukenut">lukenut</a></span>
# </td>
# <td>en ole <span class="Zzzz linkki" data-kuvaus="tm/fi/v/akt.pperf" data-kuvaus-param="{&amp;quot;8&amp;quot;:&amp;quot;lukea&amp;quot;}" lang="fi"><a href="/wiki/lukenut#Suomi" title="lukenut">lukenut</a></span>
# </td></tr>

# %% [markdown]
# #Correct fomrattig established build function to scrap

# %%
# function to visit Wiki 
# Extract data
#clean and extract
# return cleaned df
def scrape_verb(infinitive, english):
    cleaned = pd.DataFrame({'Infinitive(eng)':[f'{english}']*28,'Infinitive(FI)':[f'{infinitive}']*28})
    #cleaned['Infinitive(eng)'] = [english*28]
    #cleaned['infinitive FI'] = [infinitive*28]
    cleaned['examples'] = ['I am walking',
                       'you are walking',
                       'he/she is walking',
                       'we are walking',
                       'you(plural/respectful) are walking',
                       'they are walking',
                       '(passive) walking',
                       'I walked',
                       'You walked',
                       'he/she walked',
                       'we walked',
                       'you(plural/respectful) walked',
                       'they walked',
                       '(passive) walked',
                       'I was walking',
                       'You were walking',
                       'he/she was walking',
                       'we were walking',
                       'you(plural/respectful) were walking',
                       'they were walking',
                       '(passive) were walking',
                       'I had walked',
                       'You had walked',
                       'He/she had walked',
                       'We had walked',
                       'You(plural/repectful) had walked',
                       'They had walked',
                       '(passive) had walked'
                       ]
    doc = url.request.urlopen(f'https://fi.m.wiktionary.org/wiki/Liite:Verbitaivutus/suomi/{infinitive}').read()
    soup = bs(doc,'html.parser')
    soup.prettify()
    tables = soup.find_all('table')
    HTML(str(tables[1]))

    rows = tables[1].find_all('tr')

    y = []
    for row in rows:
        x = []
        data = row.find_all('td')
        #display(HTML(str(data)))
        for datum in data:
            i = str(datum).find('<br/>')
            if i>0:
                #print(i)
                x.append(bs(str(datum)[:i].replace('\n','') +'</td>').text)
            else:
                x.append(datum.text.replace('\n',''))
        if x:
            y.append(x)

    frame = pd.DataFrame(y)
    # present/future
    a = frame.iloc[0:7,0:3]
    # past
    b = frame.iloc[0:7,4:]
    # imperfect
    c = frame.iloc[7:,0:3]
    # past imperfect
    d = frame.iloc[7:,4:]

    for x in [a,b,c,d]:
        x.columns = ['person','positive','negative']
    #display(frame)

    verb = pd.concat([a,b,c,d],ignore_index = True)
    cleaned = cleaned.merge(verb, how = 'left', left_index = True, right_index = True)
    return cleaned


#test here
#scrape_verb('lukea','read')

# %%
test_group = pd.read_csv('./finnish verbs.csv')[7500:]
test_group.head()
test_group.shape
# Out:
# (592, 2)

# %%
total_df = pd.DataFrame()
i = 0
broken_links = []
for fin,eng in zip(test_group["Finnish infinitive"],test_group["English inifinitive"]):
    i+=1
    try:
        total_df = pd.concat([total_df,scrape_verb(fin,eng)])
    except:
        broken_links.append(fin)
        broken = test_group[test_group['Finnish infinitive']==fin]
        broken = broken[['English inifinitive','Finnish infinitive']]
        broken.columns = ['Infinitive(eng)','Infinitive(FI)']
        
        total_df = pd.concat([total_df,broken], ignore_index = True)
    if i%50 == 0:
        time.sleep(0.5)
    if i%100 == 0:
        print(i)
# Out:
# 100
# 200
# 300
# 400
# 500

# %%
broken_links

# %%
len(broken_links)
# Out:
# 504

# %%
# use pygwalker to check data quality and later for some analytics
pyg.walk(total_df)

# %%
total_df.to_csv('./cleaned verb db/7500-fv.csv',encoding = 'utf-8-sig')
